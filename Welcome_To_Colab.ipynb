# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshataKurane/Shark-Tank/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries need to install

# %%
# !pip install azure-cognitiveservices-speech
# !pip install pydub
# !pip install reportlab
# !pip install pandas
# Out:
# Requirement already satisfied: azure-cognitiveservices-speech in /usr/local/lib/python3.10/dist-packages (1.41.1)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)
# Requirement already satisfied: reportlab in /usr/local/lib/python3.10/dist-packages (4.2.5)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from reportlab) (10.4.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from reportlab) (5.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# # Transcription

# %%
import os
import time
import azure.cognitiveservices.speech as speechsdk
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib import utils
from reportlab.lib import colors
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib import colors
from reportlab.platypus import Paragraph, SimpleDocTemplate, Spacer
from reportlab.lib.styles import getSampleStyleSheet

class ConversationTranscriberWithFixedGuests:
    def __init__(self, subscription_key, region, audio_filename):
        # Initialize Speech Configuration
        self.speech_config = speechsdk.SpeechConfig(subscription=subscription_key, region=region)
        self.speech_config.speech_recognition_language = "en-US"

        # Enable speaker diarization (identify different speakers)
        self.speech_config.set_property(
            property_id=speechsdk.PropertyId.SpeechServiceResponse_DiarizeIntermediateResults,
            value='true'
        )

        # Initialize Audio Configuration
        self.audio_config = speechsdk.audio.AudioConfig(filename=audio_filename)

        # Initialize Conversation Transcriber
        self.conversation_transcriber = speechsdk.transcription. ConversationTranscriber(
            speech_config=self.speech_config,
            audio_config=self.audio_config
        )

        # Initialize speaker mapping and guest labels
        self.speaker_mapping = {}
        self.guest_labels = ["Guest 1", "Guest 2"]
        self.transcribing_stop = False

        # Store transcription results
        self.transcription_results = []

        # Connect event callbacks
        self.conversation_transcriber.transcribed.connect(self.transcribed_cb)
        self.conversation_transcriber.transcribing.connect(self.transcribing_cb)
        self.conversation_transcriber.session_started.connect(self.session_started_cb)
        self.conversation_transcriber.session_stopped.connect(self.session_stopped_cb)
        self.conversation_transcriber.canceled.connect(self.canceled_cb)
        self.conversation_transcriber.session_stopped.connect(self.stop_cb)
        self.conversation_transcriber.canceled.connect(self.stop_cb)

    def get_guest_label(self, speaker_id):
        """
        Assigns a Guest label to a speaker ID if not already assigned.
        Limits to Guest 1, Guest 2, and dynamically assigns new guests.
        """
        if not speaker_id:
            # Treat empty or None speaker_id as None
            speaker_id = "None"

        if speaker_id not in self.speaker_mapping:
            if len(self.speaker_mapping) < 2:
                # Assign next available guest label
                self.speaker_mapping[speaker_id] = self.guest_labels[len(self.speaker_mapping)]
            else:
                # Assign 'Unknown' for unidentified speakers
                self.speaker_mapping[speaker_id] = "Unknown" if speaker_id == "None" else f"Guest {len(self.speaker_mapping) + 1}"

        return self.speaker_mapping[speaker_id]

    def transcribed_cb(self, evt: speechsdk. SpeechRecognitionEventArgs):
        """
        Callback for when a segment of speech has been transcribed.
        """
        if evt.result.reason == speechsdk.ResultReason.RecognizedSpeech:
            speaker_label = self.get_guest_label(evt.result.speaker_id)
            result_text = f"{speaker_label}: {evt.result.text}"
            print(result_text)
            self.transcription_results.append(result_text)
        elif evt.result.reason == speechsdk.ResultReason.NoMatch:
            # Optionally handle NoMatch cases if needed
            pass  # Ignoring NoMatch for cleaner output

    def transcribing_cb(self, evt: speechsdk. SpeechRecognitionEventArgs):
        """
        Callback for when the transcription is ongoing (intermediate results).
        """
        if evt.result.reason == speechsdk.ResultReason.RecognizedSpeech:
            speaker_label = self.get_guest_label(evt.result.speaker_id)
            result_text = f"{speaker_label}: {evt.result.text}"
            print(result_text)
            self.transcription_results.append(result_text)

    def session_started_cb(self, evt: speechsdk.SessionEventArgs):
        """
        Callback for when the transcription session starts.
        """
        # Omit print to keep output clean
        pass

    def session_stopped_cb(self, evt: speechsdk.SessionEventArgs):
        """
        Callback for when the transcription session stops.
        """
        # Omit print to keep output clean
        pass

    def canceled_cb(self, evt: speechsdk.SessionEventArgs):
        """
        Callback for when the transcription is canceled.
        """
        # Omit print to keep output clean
        pass

    def stop_cb(self, evt: speechsdk.SessionEventArgs):
        """
        Callback to signal the transcription should stop.
        """
        self.transcribing_stop = True

    def recognize_from_file(self):
        """
        Starts the transcription process and waits for it to complete.
        """
        self.conversation_transcriber.start_transcribing_async()
        # Optionally, print a start message
        # print("Transcription started...")

        # Wait until the transcription session signals to stop
        while not self.transcribing_stop:
            time.sleep(0.5)

        self.conversation_transcriber.stop_transcribing_async()
        # Optionally, print a stop message
        # print("Transcription stopped.")

        # Save results to PDF
        self.save_to_pdf()

    def save_to_pdf(self):
      """
      Saves the transcription results to a PDF file with different colors for each guest,
      adding a blank line after each guest's transcription.
      """
      pdf_filename = "/content/SharkTank/TranscriptionOutput.pdf"
      doc = SimpleDocTemplate(pdf_filename, pagesize=letter)
      elements = []

      # Add title
      styles = getSampleStyleSheet()
      title_style = styles['Title']
      title = Paragraph("Transcription", title_style)
      elements.append(title)
      elements.append(Spacer(1, 12))

      # Define colors for each guest
      guest_colors = {
          "Guest 1": colors.navy,
          "Guest 2": colors.teal,
          "Unknown": colors.red,
      }

      # Define a style for the paragraphs
      para_style = styles['BodyText']
      para_style.alignment = 4  # Justified

      for line in self.transcription_results:
          # Get the guest label from the line
          guest_label = line.split(":")[0]  # Assuming format "Guest X: text"

          # Set the text color based on the guest label
          para_style.textColor = guest_colors.get(guest_label, colors.black)

          # Create a paragraph with the current line
          paragraph = Paragraph(line, para_style)
          elements.append(paragraph)
          elements.append(Spacer(1, 12))  # Add a blank line after each guest's transcription

      # Build the PDF
      doc.build(elements)
      print(f"Transcription saved to {pdf_filename}")

def main():
    try:
        # Replace with your actual subscription key and region
        subscription_key = " 2f3cec9a9e654383ba27a90952c1cadf"  # Replace with your actual key securely
        region = "centralindia"

        # Path to your audio file
        audio_filename = "/content/SharkTank/ABsPodcastLarge.wav"

        # Verify that the audio file exists
        if not os.path.exists(audio_filename):
            print(f"Audio file not found at path: {audio_filename}")
            return

        # Initialize the transcriber with your credentials and audio file
        transcriber = ConversationTranscriberWithFixedGuests(subscription_key, region, audio_filename)

        # Start the transcription process
        transcriber.recognize_from_file()

    except speechsdk. CognitiveServicesSpeechException as e:
        print(f"Speech SDK Error: {e}")
    except Exception as err:
        print(f"Encountered exception: {err}")

if __name__ == "__main__":
    main()
# Out:
# Guest 1: Welcome everyone to another edition of the Tony Siriani Podcast. I am thrilled to have owner Erzan with us. He is the head of Alliance Bernstein Private Wealth. So thanks for being with us, owner.
# Guest 2: Thank you, Tony. Thanks for having me.
# Guest 1: Well, my pleasure. Say, you know, Alliance Bernstein has an old, you know, well known name on Wall Street, right? So it and it has.
# Guest 1: History. Just do me a favor, give me an update on on on where it is today.
# Guest 2: Sure. I always joke with my colleagues that sometimes we are a well kept secret on Wall Street because we have always the global reach and scale of a large asset manager. We manage close to $800 billion, but then we still have an intimate private wealth management business. It's a entrepreneurial part of our culture and.
# Guest 2: Our integrated asset and wealth management business and I call it entrepreneurial and intimate because we operate out of 20 offices and we have 300 advisors. So you have a little bit of that global resources in the background that our clients and advisors can access, but we still have a strong culture that is tightly knit together and we are very proud of our history as well. Well, you know the.
# Guest 1: Whole that that brings up an immediate, you know, question for me, which is so you have 300.
# Guest 1: 300 billion is an enormous, you know, number, right? And you have 300 advisors and, you know, culturally the advisors and the money managers, I mean, they're sort of in proximity, right? And some of the offices. And I'm just wondering how, how that dynamic works to sort of help a wealth manager. You know, I'm, I'm thinking specifically, are they reaching out to the money manager? Are the money managers, you know, wanting to be part of that? Or how do you, how do you?
# Guest 2: Manage that? No, absolutely. I think it's something that really sets us apart.
# Guest 2: I really feel the connectivity and proximity to how the money is managed is a differentiated capability and insight we have. Let me use an example to bring it to life, right. So remember in 2022 we had some challenges with the regional banking crisis, right at that moment, you know, everybody including us got some got quite nervous about the direction of the markets, what's going to happen, what's going to.
# Guest 2: Into the financial system, banks, etcetera. And in that moment like within you know less than 24 hours, we were able to get our community bank equity product PM. We got the financial research team members from our different equity teams. We managed 20 separate active equity strategies on the asset management umbrella, which obviously supports both our wealth business, but also our third party distribution on the asset management side.
# Guest 2: And having that kind of connectivity and we put out a Zoom with all these subject matter experts, open it up to all of our advisors, Everybody could ask their questions. And then again, after another 24 hours, we opened it up to our clients. I think the speed and the breadth of experience that we can bring together is really remarkable. It was one of the really proud moments.
# Guest 2: At least in my experience, I.
# Guest 1: I think compare that to your, your typical RIA that has, you know, absolutely no access to that or.
# Guest 1: You know, typically it's really hard to get access to, to asset managers, you know, to talk to your clients or get information. So yeah, I consider that a huge advantage.
# Guest 2: No, absolutely. It also carries itself to now privates, right. So we also manage significant amount of private alternatives, primarily private credit assets around $60 billion. And you know recently again one other example to bring it to life, there's been a lot of questions about.
# Guest 2: About whether we hit the bottom in the real estate cycle, what's going to happen to commercial real estate, all those kind of questions. And we were able to curate a panel of, again, investors from our different private credit teams that we work with. And then we put them in a roadshow and put it in front of our clients in different local offices. Again, a great collaboration.
# Guest 1: It's a huge differentiator. You know, my feeling is that AI is coming, right? So AI is going to be able to, you know, it can only look backwards, right? And and it can only look at publicly.
# Guest 1: Created information, but it is going to be able to start saying well, these are the best ETFs and this is the best you know it's going to it's going to be a challenge for advisors. So if I'm looking to differentiate myself, I really need to have access to the private markets, right? Because that's something that AI can't do because it's not public information, right? So you're talking about giving yourself an advantage with clients. I think that in the future it's only going to get be more important.
# Guest 2: No 100% and.
# Guest 2: The other aspect of it is, you know, obviously.
# Guest 2: Investment solutions is, is critical. But the other way to differentiate is, you know, the holistic advice. I know it's a slightly overused word, holistic advice, but we really emphasize also on the softer aspects of the complexity of wealth, right, Given our focuses, high net worth and ultra high network clients, I mean we know that there is more demand for advice and holistic thinking.
# Guest 2: Post the COVID right now.
# Guest 2: People want to have more in person or remote but human touch. And within that, it's not only the hard content of the product or the, you know, financials behind the financial plan, but it's all about the broader thinking, whether it's a family governance, family values, succession in family businesses. There are a lot of broader topics that cannot be, I think it is today.
# Guest 2: Can be automated through generative AI or other forms of advanced analytics.
# Guest 1: You know, absolutely. And you also bring up a, you know, a point and advisers don't like to think about this, but but as a practical matter, you know, if you don't have 5 million dollars, $6 million, the estate planning thing becomes less and less important. But when you have over that number, you do really need somebody who's on top of it and can help you and access, you know, services. Because as a as a practical matter, you know, wealth managers need support, you know, attorneys, lawyers, whatever it might be, but the resources to do it.
# Guest 2: 100% and in our busy lives.
# Guest 2: Bringing it all together is also very important, right? So obviously we have a great network of state lawyers, other advisors, bankers, accountants and the list goes on. But ultimately you need to be able to put it all together and make it easy for the kind of individual to navigate the complexity, right? And having a little bit of an independent quote UN quote quarterback who could also, you know, sit on the side of the client to be able to put it together.
# Guest 2: And draw implications.
# Guest 1: Yeah, yeah. Critically important. And again, differentiated from a standard RIA that has to go out and search all that stuff. You have to sort of, you know, put it together and you and you cobble together sort of a Frankenstein instead of having something that's, you know, organized.
# Guest 2: 100%, yeah. You know, again, it's the balance between having the scale and resources while not creating bureaucracies so they can be nimble and be really client driven, yeah.
# Guest 1: Yeah, that's great.
# Guest 1: And also, you know, relationship through equitable, it's a strong balance sheet. So that's that's also I think a differentiator from some of the other, you know, folks out there in the RIAA world or that are looking to roll up Rias. I mean, there's a that's the competition out there you.
# Guest 2: Know, yeah, for sure, again, we are quite unique in that regard as well. Obviously, we are also New York Stock Exchange listed, so we have our own.
# Guest 2: Sources of capital and can tap into capital markets through that.
# Guest 2: And then Equitable is a strategic shareholder and we have a lot of collaboration with them on different types of initiatives. You know, it's a wide range, but for instance, that's one of the private alternatives, one of the areas that we work with together with Equitable managing a large chunk of the Equitable balance sheet.
# Guest 1: Yeah, fantastic. Well, patient capital, right, that that's what you would call.
# Guest 1: That.
# Guest 2: Yeah, yeah. No, absolutely. I mean, look.
# Guest 2: You have been a pioneer and a veteran of this industry.
# Guest 2: You know this, I mean right now there's so much financial capital chasing opportunities in the space. I think there is a little bit of extreme bias on thinking about EBITDA and how many deals and all that. Obviously we are growth driven as well. But ultimately we take a long term view. We we want to be the patient capital looking for the right opportunities versus trying to solve for a number in a.
# Guest 1: Spreadsheet, yeah, yeah, I, I and I think that that that's another differentiator too, right. I mean.
# Guest 1: The the, the idea of long term and and that typically comports with an advisor trying to build an ultra high net worth business, you know as well, because I think those type of clients understand that.
# Guest 2: 100% And as you know, typically the wealth formation at the Ultra Network client level is tied to some liquidation or monetization event, right? It could be tied to a business.
# Guest 2: Or some other hard asset. So you need to take a long term view because you might not have all the liquid assets to manage on day one, but you need to stay with the client, add value and then.
# Guest 2: Wait for that day that they will have, you know, larger pools of liquid assets to be managed.
# Guest 1: No question about that. Well, something else I think that's interesting is so if I'm an RIAA and I'm on my own, right, I can see the advantages here because I've got, you know, it's not just the patient capital, it's the these resources and things that, that that you guys bring to the table. But one of the big concerns, you know, as our business ages, right and as advisors are getting older.
# Guest 1: It's really hard to find partners.
# Guest 1: It's really hard to get up. I mean, you could have all the plans you want for succession, but if you don't have anybody to execute it or you don't have a partner who's really needing to invest in your business or find somebody else to help you, it's really difficult to do, Yeah.
# Guest 2: 100% it's also lifetime worth of investments in these practices, right? So it's typically your baby and you need to find the the transition solution for yourself, for your family and for your clients. It's a very personal.
# Guest 2: Affair. So that's why I think it's important to understand the fit both between the advisor that's looking for a new platform and the platform itself. And I don't think there's one-size-fits-all. But again, for the advisors that are really kind of high net worth, also high net worth oriented looking for a longer term solution, very investment and holistic planning driven both hard and software elements of planning.
# Guest 2: I think we offer a pretty good.
# Guest 1: Solution. Yeah and and you know the ability maybe for trainees or there there's a there's a program where you can get some younger brokers involved in their businesses too A.
# Guest 2: 100% actually for the ones that have been in the industry for a long time, they know it. I mean Bernstein's training and advisor development has been one of the big kind of differentiators and calling cards we always.
# Guest 2: Have been a great contributor to the industry by attracting new talent to the industry, developing them in our model.
# Guest 2: And then that's part of the secret sauce, if you will, by having very committed, high high quality and highly performing advisors coming off the ranks from our recruiting system and training. But ultimately, you know, when you get to a larger scale, you need to balance your recruiting program as well. Of course, we will always be very driven by the fresh talents in terms of bringing and molding them in our model, but we also know that there are.
# Guest 2: Advisors out there, we can also incorporate into our teams at different levels. So it's not a single approach. We can use multiple paths to recruiting.
# Guest 1: Yeah. Well, and again, I think that the typical, you know, Rias that are out there that are, you know, rolling along with pop, you know, venture money and doing rollups, they don't have anything like that. There's just no, they just have no access to it.
# Guest 2: Absolutely.
# Guest 1: So if I was if, if you were when when you tell the story, I mean, we talked about a bunch of things that are, you know, highlights when you when you're sitting with advisors and telling, you know, the Alliance Bernstein story. What do you think resonates most with them out of all those things?
# Guest 2: I mean a the pure focus, right. So we are not a financial conglomerates and we are a pure asset and wealth management firm. So we understand and talk investments. We can deliver complex investment outcomes. I think with most of the advisors that pure focus and expertise matters.
# Guest 2: Second, given we have a long standing more than 50 years of history across both of these businesses.
# Guest 2: We are again publicly listed company also with a large shareholder. We can take a very long term view into building and growing businesses rather than looking for the short term monetary gain and exits. I think that long term patient capital that we touched on really resonates with the advisors because they're looking for individuals who can invest in their practice.
# Guest 2: And then the final thing is culture. I mean, culture is something that you can only experience.
# Guest 2: It's hard to talk about it, but I always take pride in not only our client centricity and that client fiduciary mindset with the pure fee based business model, but also at the same time I take pride in our internal collaboration because the magic happens when you bring the best of a firm in front of the clients. And I think we do a great job in terms of having that collaboration while we are very intellectually curious bunch and we might have different points of view.
# Guest 2: But ultimately, we bring the best together to serve the clients.
# Guest 1: So if I was sitting there, I guess prior to this conversation or prior to you and I talked, we've talked a couple times. So I would, I would have said, oh, this, you know, Alex Bernstein, it's really for breakaway advisors from wirehouse. I think that would be the the, but it's not just that, right. You got, it's a tell us a little bit about the type of advisors you're either looking for or that, that you, you, you, you you think work very well in your system. Yeah, sure.
# Guest 2: The the the targets.
# Guest 2: Profile would be first of all, again, high net worth and ultra network is our focus, right. So if you are focused on different types of client segments, maybe we.
# Guest 1: Might you have to be a nice person too?
# Guest 1: Right, you don't want to.
# Guest 2: Yeah, that, that too. So I think your client's profile matters because we are relatively sophisticated platform and and hence we lead with that and that will be important to have the right fit with the clients. We are definitely looking for advisors that kind of take a holistic approach to their clients is not only the as I mentioned.
# Guest 2: Just a ******** product focus product is important. You need to articulate your capital markets views, but ultimately how do you think about we can longer term financial planning, estate planning, business sales, how to be efficient with that, how to bring family governance, family values in certain cases on the higher end family office type of capabilities. So as AI think you need.
# Guest 2: A relatively holistic tinker as an advisor versus AI will just sell product quote UN quote, right? That's not the model we are looking for.
# Guest 2: And ultimately we are looking for entrepreneurial folks who are committed to growing their business because at the end of the day, great things happen when we are all growing together and that that is part of our DNA in the Bernstein private wealth, the entrepreneurial growth oriented culture.
# Guest 1: And that's RI, as you know, bank, you know, private bankers, bank people in the bank, all that, everything.
# Guest 2: 100%, yeah, exactly. I don't think we have a bias for one business model versus the other.
# Guest 2: Again, just that depends on the preferences and characteristics of the advisor himself or herself. And by the way, I'm emphasizing to herself part, I mean we believe one of the biggest opportunities in wealth management is the growing role of women in financial decision making as the main decision maker in main households. A because of growing female executives and leaders in different businesses, but also the whole.
# Guest 2: Demographics of.
# Guest 2: Woman inheriting more wealth and our ability to really have differentiated solutions for for for those clients.
# Guest 1: Yeah, we have a we have a great women's advisor network here at Advisor Hub. It works great. And 100%, you know, we're aligned with with that thinking it's just good business sense. So you know, help figure that out 100%. So lastly, believe it or not, we're already you know, 20 minutes or so, but.
# Guest 1: It's just my daughter just got in this business. So Speaking of women in the business, right, So thank you. She's studying for relationship with an old woman firm too. So it's kind of fun.
# Guest 1: And she studied to get her her license so.
# Guest 1: What if your kids are getting to this business? What are you telling me? You think there's a bright future here in wealth management or, or? What would you say?
# Guest 2: Absolutely. I'm very passionate about this business and I, I, I, I wish my kids who are young will be interested in financial services and wealth management. It will be fun to see them in action. The reason I'm very bullish is a, there's a lot of.
# Guest 2: Innovation in broader financial services and wealth management. So there's a.
# Guest 2: Evergreen opportunity to add value to clients as a financial advisor by bringing new set of tools capabilities. We haven't touched a lot on technology beyond the AI conversation. So technology offers a lot of opportunities both for clients and advisors to build really scalable practices really delight the clients with a differentiated experience whether storm boarding where there's a reporting, whether it's.
# Guest 2: The engagement overall, and on top of that there is a growing set of complexities in people's lives.
# Guest 2: You know, not to mention the shortage of time to spend on your personal financial affairs, but you know, think about all the things that you need to deal with, you know, now ETFs, Smas, alternatives, crypto and the list goes on. And for the average individual, even for the very well educated, sophisticated client, they need a hand holding, they need their guides and I think with the possibilities of innovation.
# Guest 2: With the needs of the clients, it's a phenomenal.
# Guest 2: Place where the supply of capabilities matches with the future demands and it's a hard profession so as a result only the best make it to the end So as a result there's not going to be you know millions of successful financial advisors This is the the beauty and challenge of this business but the the best advisors I think will continue to have very prosperous careers and they will add tremendous amount of value for their clients That's why I'm.
# Guest 1: Passionate, fantastic. Well, look, I'm going to end on that.
# Guest 1: That's a high note. So I like that idea. Well, thank, thank you owner for being on the show. We'll have we'll have more of these conversations. I really appreciate.
# Guest 2: You being here, no thank you. Look forward to.
# Guest 3: Staying in touch? Great.
# Transcription saved to /content/SharkTank/TranscriptionOutput.pdf

# %% [markdown]
# # Summarization

# %%
import os
import re
from collections import Counter
import PyPDF2
from fpdf import FPDF
import matplotlib.pyplot as plt
import seaborn as sns
from openai import AzureOpenAI

# Azure OpenAI configuration
OPENAI_API_VERSION = "2024-02-01"
AZURE_OPENAI_ENDPOINT = "https://hexavarsity-secureapi.azurewebsites.net/api/azureai"
AZURE_OPENAI_API_KEY = "04a13dcb07aabdac"  # Provide your API key here

client = AzureOpenAI(api_version=OPENAI_API_VERSION, azure_endpoint=AZURE_OPENAI_ENDPOINT, api_key=AZURE_OPENAI_API_KEY)

# Read the content of the PDF file using PyPDF2
file_path = "/content/SharkTank/TranscriptionOutput.pdf"
file_content = ""
with open(file_path, 'rb') as file:  # Open in binary read mode 'rb'
    pdf_reader = PyPDF2.PdfReader(file)
    for page_num in range(len(pdf_reader.pages)):
        page = pdf_reader.pages[page_num]
        file_content += page.extract_text()

# Extract dynamic data
def extract_speaker_turns_and_word_count(text):
    speaker_turns = Counter()
    word_count = Counter()
    speakers = re.findall(r'(Guest \d+):', text)
    for speaker in speakers:
        speaker_turns[speaker] += 1
    for speaker in speaker_turns:
        words = re.findall(rf'{speaker}: (.*?)\n', text, re.DOTALL)
        word_count[speaker] = sum(len(word.split()) for word in words)
    return speaker_turns, word_count

def extract_topic_segmentation(text):
    topics = re.findall(r'(\d+\.\s.*?)(?=\s\d+\.\s|$)', text)
    return {topic: int(time) for topic, time in topics}

speaker_turn_count, total_word_count = extract_speaker_turns_and_word_count(file_content)
topic_segmentation = extract_topic_segmentation(file_content)

# Create the prompt
prompt = f"""
You are a helpful assistant. Here is a text:

{file_content}

*Note :- Do not bold or highlight any text let the output be normal & properly format the spacing and alignments *

1. Details of speaker:(font size 16)

Guest 1:
Designation & Company:
Guest 2:
Designation & Company:

2. Utterance is the Main conversation that occurred, having said that give the name SUMMARY(font size 16) and Give a combined detailed summary of the utterances from pdf(the pdf is likely to be on finance) make sure the summary is readable so every line should only contain certain words and then use next line but give one page detailed summary in a single paragraph(it should fit in one page),

3. Question and Answer:-(font size 16)
   Identify and list out ALL the questions and Answers asked form the pdf Make sure you provide the relevant answer to the question asked.
(like
      Question 1:
      Answer :
      Question 2
      Answer:
).
4. "LIST OF COMPANIES"(font size 16) discussed in the conversation.(please don't hallucinate and stick to pdf.)

5. Sentiment Over Time:
Sentiment analysis plotted over the duration of the conversation to show how sentiment changes.
"""
prompt = prompt.replace("'", "''")

# Make the API call
res = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant give answers for the questions asked by user"},
        {"role": "user", "content": prompt}
    ],
    temperature=0.7,
    max_tokens=900,
    top_p=0.6,
    frequency_penalty=0.7
)

# Get the response content
response_content = res.choices[0].message.content

# Print the response content to the console
print("Transcript Analysis:")
print(response_content)

# Print the extracted data to the console
print("\nSpeaker Turn Count:")
for speaker, count in speaker_turn_count.items():
    print(f"{speaker}: {count}")

print("\nTotal Word Count:")
for speaker, count in total_word_count.items():
    print(f"{speaker}: {count}")

# Create a new PDF with the response content
class PDF(FPDF):
    # Removed the header and footer methods

    def chapter_title(self, title):
        self.set_font("Arial", "B", 12)  # Bold font for titles
        self.cell(0, 10, title, 0, 1, "L")
        self.ln(10)

    def chapter_body(self, body):
        self.set_font("Arial", "", 10)  # Normal font for body text
        body = body.encode('utf-8', 'replace').decode('latin-1')
        self.multi_cell(0, 10, body)
        self.ln()

new_pdf_path = "/content/SharkTank/Summarization.pdf"
pdf = PDF()
pdf.add_page()
pdf.chapter_title("Transcript Analysis")
pdf.chapter_body(response_content)
pdf.output(new_pdf_path)

# Visualization part
# Create pie chart for Speaker Turn Count
plt.figure(figsize=(10, 7))
plt.pie(speaker_turn_count.values(), labels=speaker_turn_count.keys(), autopct='%1.1f%%', startangle=140)
plt.title('Speaker Turn Count')
plt.savefig('/content/SharkTank/SpeakerTurnCount.png')
plt.close()

# Create bar graph for Total Word Count
plt.figure(figsize=(10, 7))
sns.barplot(x=list(total_word_count.keys()), y=list(total_word_count.values()))
plt.title('Total Word Count')
plt.xlabel('Speakers')
plt.ylabel('Word Count')
plt.savefig('/content/SharkTank/TotalWordCount.png')
plt.close()

# Merge the new PDF with the existing PDF and add images
output_pdf_path = "/content/SharkTank/CombinedOutput.pdf"
with open(new_pdf_path, 'rb') as new_file, open(file_path, 'rb') as existing_file:
    new_pdf = PyPDF2.PdfReader(new_file)
    existing_pdf = PyPDF2.PdfReader(existing_file)
    pdf_writer = PyPDF2.PdfWriter()

    # Add pages from the summarization PDF first
    for page_num in range(len(new_pdf.pages)):
        pdf_writer.add_page(new_pdf.pages[page_num])

    # Add pages from the transcription PDF next
    for page_num in range(len(existing_pdf.pages)):
        pdf_writer.add_page(existing_pdf.pages[page_num])

    # Add images to the PDF
    pdf_with_images = PDF()
    pdf_with_images.add_page()
    pdf_with_images.chapter_title("Visualizations")
    if os.path.exists('/content/SharkTank/SpeakerTurnCount.png'):
        pdf_with_images.image('/content/SharkTank/SpeakerTurnCount.png', x=10, y=30, w=90, h=60)
    if os.path.exists('/content/SharkTank/TotalWordCount.png'):
        pdf_with_images.image('/content/SharkTank/TotalWordCount.png', x=110, y=30, w=90, h=60)
    pdf_with_images.output("/content/SharkTank/Visualizations.pdf")

# Merge the visualizations PDF with the combined PDF
with open("/content/SharkTank/Visualizations.pdf", 'rb') as visualizations_file:
    visualizations_pdf = PyPDF2.PdfReader(visualizations_file)
    for page_num in range(len(visualizations_pdf.pages)):
        pdf_writer.add_page(visualizations_pdf.pages[page_num])

with open(output_pdf_path, 'wb') as output_file:
    pdf_writer.write(output_file)

print(f"Merged PDF saved to {output_pdf_path}")
# Out:
# Transcript Analysis:
# 1. Details of speaker:
#
# Guest 1: Tony Siriani
# Designation & Company: Host, Tony Siriani Podcast
#
# Guest 2: Erzan
# Designation & Company: Owner, Alliance Bernstein Private Wealth
#
# 2. SUMMARY
# In the latest episode of the Tony Siriani Podcast, host Tony welcomes Erzan, owner of Alliance Bernstein Private Wealth. They discuss the firm’s impressive management of nearly $800 billion in assets while maintaining a close-knit culture with 300 advisors across 20 offices. Erzan emphasizes the unique connectivity between wealth managers and money managers at Alliance Bernstein, allowing for rapid response to market changes, exemplified during the regional banking crisis in 2022. The conversation highlights how their integrated asset and wealth management approach fosters collaboration among teams and provides clients with timely insights. They also touch on the importance of private markets as a competitive advantage against AI-driven investment strategies that focus solely on public data. Furthermore, they discuss holistic advice that goes beyond financial products to include family governance and succession planning for high-net-worth clients. The conversation underscores the significance of having a strong support network for estate planning and integrating various advisory services to simplify complex financial situations for clients. As they explore advisor recruitment, they note that Alliance Bernstein values entrepreneurial advisors focused on long-term growth rather than short-term gains. The discussion also acknowledges the growing role of women in financial decision-making as an important demographic shift within wealth management. Finally, both speakers express optimism about the future of wealth management due to ongoing innovations in technology and increasing complexities in client needs.
#
# 3. Question and Answer:
#
# Question 1: Can you give me an update on where Alliance Bernstein is today?
# Answer: We manage close to $800 billion with an intimate private wealth management business operating out of 20 offices with 300 advisors.
#
# Question 2: How does the dynamic work between advisors and money managers?
# Answer: Our connectivity allows us to quickly respond to market challenges by bringing together subject matter experts for our advisors.
#
# Question 3: What differentiates your firm from typical RIAs?
# Answer: We have access to private markets which AI cannot replicate; our holistic advice encompasses broader aspects like family governance.
#
# Question 4: What is your view on estate planning for high-net-worth individuals?
# Answer: It becomes crucial when you exceed certain asset thresholds; we provide comprehensive resources including attorneys and accountants.
#
# Question 5: What kind of advisors are you looking for at Alliance Bernstein?
# Answer: We seek high-net-worth-focused advisors who take a holistic approach rather than just selling products.
#
# Question 6: Is there a bright future in wealth management?
# Answer: Absolutely! There’s innovation happening continuously which aligns supply capabilities with client demands.
#
# 4. LIST OF COMPANIES discussed in the conversation:
# - Alliance Bernstein
# - Equitable
#
# 5. Sentiment Over Time:
# The sentiment analysis throughout this conversation indicates an overall positive outlook regarding opportunities within wealth management while addressing challenges faced by traditional RIAs compared to larger firms like Alliance Bernstein.
#
#
# Speaker Turn Count:
# Guest 1: 33
# Guest 2: 61
# Guest 3: 1
#
# Total Word Count:
# Guest 1: 503
# Guest 2: 831
# Guest 3: 4
# Merged PDF saved to /content/SharkTank/CombinedOutput.pdf
